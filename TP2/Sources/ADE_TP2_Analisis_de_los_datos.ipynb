# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaloAcost4/ADE2026_TpiUniversidad/blob/main/TP2/Sources/ADE_TP2_Analisis_de_los_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de los datos de cada source
# Para saber que problemas tenemos :)

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dfCur = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/curso.csv')
dfCurProg = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/curso_programa.csv')
dfDep = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/departamento.csv')
dfDic = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/dictado.csv')
dfDoce = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/docente.csv')
dfEst = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/estudiante.csv')
dfEvaCur = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/evaluacion_curso.csv')
dfEx = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/examen.csv')
dfFac = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/facultad.csv')
dfIns = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/inscripcion.csv')
dfPro = pd.read_csv('/content/drive/MyDrive/UTN/ADE/TP2/SourcesUniversidad/programa.csv')

# %% [markdown]
# ## Estudiante:

# %%
dfEst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130000 entries, 0 to 129999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_estudiante     130000 non-null  int64
#  1   dni               130000 non-null  object
#  2   apellido          130000 non-null  object
#  3   nombre            130000 non-null  object
#  4   genero            130000 non-null  object
#  5   fecha_nacimiento  130000 non-null  object
#  6   email             126030 non-null  object
#  7   telefono          123549 non-null  object
#  8   nacionalidad      127264 non-null  object
#  9   id_programa       130000 non-null  int64
#  10  anio_ingreso      130000 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 10.9+ MB

# %% [markdown]
# * Dni es object.
# * Email, telefono y nacionalidad tienen nulos.
# * Datos requeridos: id_estudiante, dni, apellido, nombre, fecha_nacimiento, id_programa, anio_ingreso

# %% [markdown]
# ### DNI

# %%
len(dfEst[(dfEst['dni'] == '') | (dfEst['dni'] == ' ')])
# Out:
# 0

# %%
patrones = dfEst['dni'].astype(str).str.replace(r'\d', '#', regex=True)
print(patrones.value_counts())
# Out:
# dni
# ########      119501
#  ########       5317
# ##.###.###      5182
# Name: count, dtype: int64

# %%
dfEst['dni'].astype(str).str.strip().str.replace('.', '').str.len().value_counts()
# Out:
# dni
# 8    130000
# Name: count, dtype: int64

# %% [markdown]
# ### Genero

# %%
dfEst.genero.unique()
# Out:
# array(['M', 'F', '1', 'Femenino', 'male', '2', 'm', 'Masculino', 'female',
#        'f'], dtype=object)

# %%
dfEx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890389 entries, 0 to 890388
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_examen       890389 non-null  int64
#  1   id_inscripcion  890389 non-null  int64
#  2   fecha           890389 non-null  object
#  3   nota            890389 non-null  float64
#  4   numero_intento  890389 non-null  int64
#  5   resultado       890389 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 40.8+ MB

# %%
dfEx[dfEx['nota'].isna()]
# Out:
# Empty DataFrame
# Columns: [id_examen, id_inscripcion, fecha, nota, numero_intento, resultado]
# Index: []

# %% [markdown]
# ### Fecha_nacimiento

# %%
patronesFecha = dfEst['fecha_nacimiento'].astype(str).str.replace(r'\d', '#', regex=True)
print(patronesFecha.value_counts())
# Out:
# fecha_nacimiento
# ####-##-##    114462
# ##/##/####      5129
# ####            3894
# ##-##-####      3884
# ########        2631
# Name: count, dtype: int64

# %% [markdown]
# ### Nacionalidad

# %%
dfEst.nacionalidad.unique()
# Out:
# array(['Argentina', 'Chilena', 'Paraguaya', 'Brasileña', 'Venezolana',
#        'Colombiana', 'Boliviana', 'Peruana', nan, 'Uruguaya'],
#       dtype=object)

# %%
dfEst[dfEst['nacionalidad'].isna()][['id_estudiante', 'nacionalidad']]
# Out:
#         id_estudiante nacionalidad
# 104               105          NaN
# 138               139          NaN
# 197               198          NaN
# 212               213          NaN
# 229               230          NaN
# ...               ...          ...
# 129837         129838          NaN
# 129886         129887          NaN
# 129889         129890          NaN
# 129937         129938          NaN
# 129938         129939          NaN
#
# [2736 rows x 2 columns]

# %% [markdown]
# Hay que ver como tratar esto, agregar la clase "No especificado" o asumir que son Argentinos.

# %% [markdown]
# ## Examen:
